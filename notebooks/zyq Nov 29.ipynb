# %% [markdown]
# # Nov 29

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Original data
#
# > Misra, R. et al. 2018. Decomposing fit semantics for product size recommendation in metric spaces. Proceedings of the 12th ACM Conference on Recommender Systems (New York, NY, USA, Sep. 2018), 422–426.

# %%
# ModCloth dataset

df = pd.read_json('../data/modcloth_data.json.gz', lines=True, compression='gzip')
display(df.head())
df.info()
# Out:
#    item_id  waist  size  quality cup size  hips  bra size category bust  \
# 0   123373   29.0     7      5.0        d  38.0      34.0      new   36
# 1   123373   31.0    13      3.0        b  30.0      36.0      new  NaN
# 2   123373   30.0     7      2.0        b   NaN      32.0      new  NaN
# 3   123373    NaN    21      5.0     dd/e   NaN       NaN      new  NaN
# 4   123373    NaN    18      5.0        b   NaN      36.0      new  NaN
#
#     height         user_name         length    fit  user_id  shoe size  \
# 0  5ft 6in             Emily     just right  small   991571        NaN
# 1  5ft 2in  sydneybraden2001     just right  small   587883        NaN
# 2  5ft 7in             Ugggh  slightly long  small   395665        9.0
# 3      NaN      alexmeyer626     just right    fit   875643        NaN
# 4  5ft 2in        dberrones1  slightly long  small   944840        NaN
#
#   shoe width review_summary review_text
# 0        NaN            NaN         NaN
# ...

# %%
# RentTheRunway dataset

df = pd.read_json('../data/renttherunway_data.json.gz', lines=True, compression='gzip')
display(df.head())
df.info()
# Out:
#    fit  user_id bust size  item_id  weight  rating     rented for  \
# 0  fit   420272       34d  2260466  137lbs    10.0       vacation
# 1  fit   273551       34b   153475  132lbs    10.0          other
# 2  fit   360448       NaN  1063761     NaN    10.0          party
# 3  fit   909926       34c   126335  135lbs     8.0  formal affair
# 4  fit   151944       34b   616682  145lbs    10.0        wedding
#
#                                          review_text          body type  \
# 0  An adorable romper! Belt and zipper were a lit...          hourglass
# 1  I rented this dress for a photo shoot. The the...  straight & narrow
# 2  This hugged in all the right places! It was a ...                NaN
# 3  I rented this for my company's black tie award...               pear
# 4  I have always been petite in my upper body and...           athletic
#
#                                       review_summary category height  size  \
# ...

# %% [markdown]
# ## Training set from MIRA Lab

# %%
# Training data

train_df = pd.read_json('../data/train_data.json')
train_df.replace({"": np.nan}, inplace=True)
display(train_df.head())
train_df.info()
# Out:
#                          item_name price  \
# 0          Toccin\nNude Plaid Coat  $695
# 1        Trina Turk\nTe Amo Romper  $268
# 2      Keepsake\nDreamscape Romper  $205
# 3         Hunter\nBlue Puffer Coat  $225
# 4  Keepsake\nBlack Better Days Top  $180
#
#                                       review_summary  \
# 0                                      Classy topper
# 1                                    Perfect romper!
# 2                   Short but made me feel amazing!
# 3                             Fun & Warm Winter Coat
# 4  This shirt got me SO MANY COMPLIMENTS! super b...
#
#                                               review  user_name  fit  \
# 0  Really nice piece that dresses up your outfit,...  Victoria   NaN
# 1  This romper was great! Perfect for many occasi...     Shayla  NaN
# 2  I'd say the romper typically runs true to size...         Lo  NaN
# 3  I rented this for a ski trip to vail, colorado...       Andi  NaN
# ...

# %%
# Validation data
# Note: Missing values of 'fit' need to be predicted and filled in. Here we just drop user feedback to meet the format of the testing data.

val_df = train_df.drop(
    columns=['review_summary', 'review', 'rating', 'user_name'])
val_df['fit'].replace({
    'Small': 1,
    'True to Size': 2,
    'Large': 3
},
                      inplace=True)
display(val_df.head())
val_df.info()
# Out:
#                          item_name price  fit rented_for usually_wear size  \
# 0          Toccin\nNude Plaid Coat  $695  NaN       Work            8   MR
# 1        Trina Turk\nTe Amo Romper  $268  NaN   Vacation           10    L
# 2      Keepsake\nDreamscape Romper  $205  NaN       Date            0    S
# 3         Hunter\nBlue Puffer Coat  $225  NaN   Vacation            4    S
# 4  Keepsake\nBlack Better Days Top  $180  NaN       Work            6    S
#
#   age height bust_size  weight          body_type
# 0  36  5' 9"       NaN  160LBS                NaN
# 1  30    NaN      36DD  160LBS          HOURGLASS
# 2  29    NaN       30A  120LBS  STRAIGHT & NARROW
# 3  31  5' 6"       32D  128LBS           ATHLETIC
# 4  44  5' 4"       34B  140LBS          HOURGLASS
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87766 entries, 0 to 87765
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
# ...
